# %%
import sys
sys.path.append('..')

import os, cv2
from ruamel.yaml import YAML

from modules.process import *
from modules.display import *
from modules.curvature import compute_list_divided_curvature_radii
from modules.helper import *

# %% [markdown]
# ## Load images

# %%
""" Create MyImages instance """
def create_dust_mask(instance):
    dust_mask = instance.dust_mask.copy()
    cv2.circle(dust_mask, (100, 148), 16, color=1, thickness=-1)
    cv2.circle(dust_mask, (523, 305), 13, color=1, thickness=-1)
    cv2.circle(dust_mask, (450, 483), 11, color=1, thickness=-1)
    return dust_mask

conf = load_yaml('conf.yaml')

instance0 = MyImages()
instance0.load_image(conf['path'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_65285/1819257159.py in ?()
#       8
#       9 conf = load_yaml('conf.yaml')
#      10
#      11 instance0 = MyImages()
# ---> 12 instance0.load_image(conf['path'])
#
# ~/workspace/PhaseContrastImageAnalysis/src/template/../modules/process.py in ?(self, path)
#      15     def load_image(self, path):
# ---> 16         self.gray_images = skimage.io.imread(path, plugin="tifffile")
#      17         self.dust_mask = np.zeros(self.gray_images[0].shape)
#
# ~/workspace/Droplet/venv/lib/python3.10/site-packages/skimage/io/_io.py in ?(fname, as_gray, plugin, **plugin_args)
#      49         if fname.lower().endswith(('.tiff', '.tif')):
#      50             plugin = 'tifffile'
#      51
#      52     with file_or_url_context(fname) as fname:
# ---> 53         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      54
#      55     if not hasattr(img, 'ndim'):
#      56         return img
#
# ~/workspace/Droplet/venv/lib/python3.10/site-packages/skimage/io/manage_plugins.py in ?(kind, *args, **kwargs)
#     201             func = [f for (p, f) in plugin_funcs if p == plugin][0]
#     202         except IndexError:
#     203             raise RuntimeError(f'Could not find the plugin "{plugin}" for {kind}.')
#     204
# --> 205     return func(*args, **kwargs)
#
# ~/workspace/Droplet/venv/lib/python3.10/site-packages/skimage/io/_plugins/tifffile_plugin.py in ?(fname, **kwargs)
#      70     """
#      71     if 'img_num' in kwargs:
#      72         kwargs['key'] = kwargs.pop('img_num')
#      73
# ---> 74     return tifffile_imread(fname, **kwargs)
#
# ~/workspace/Droplet/venv/lib/python3.10/site-packages/tifffile/tifffile.py in ?(files, selection, aszarr, key, series, level, squeeze, maxworkers, buffersize, mode, name, offset, size, pattern, axesorder, categories, imread, sort, container, chunkshape, dtype, axestiled, ioworkers, chunkmode, fillvalue, zattrs, multiscales, omexml, out, out_inplace, _multifile, _useframes, **kwargs)
#    1102                     )
#    1103                     if selection is None:
#    1104                         return store
#    1105                     return zarr_selection(store, selection, out=out)
# -> 1106                 return tif.asarray(
#    1107                     key=key,
#    1108                     series=series,
#    1109                     level=level,
#
# ~/workspace/Droplet/venv/lib/python3.10/site-packages/tifffile/tifffile.py in ?(self, key, series, level, squeeze, out, maxworkers, buffersize)
#    4344             result = page0.asarray(
#    4345                 out=out, maxworkers=maxworkers, buffersize=buffersize
#    4346             )
#    4347         else:
# -> 4348             result = stack_pages(
#    4349                 pages, out=out, maxworkers=maxworkers, buffersize=buffersize
#    4350             )
#    4351
#
# ~/workspace/Droplet/venv/lib/python3.10/site-packages/tifffile/tifffile.py in ?(pages, tiled, lock, maxworkers, out, **kwargs)
#   22603                 filecache.close(page.parent.filehandle)
#   22604
#   22605         if maxworkers < 2:
#   22606             for index, page in enumerate(pages):
# > 22607                 func(page, index)
#   22608         else:
#   22609             page0.decode  # init TiffPage.decode function
#   22610             with ThreadPoolExecutor(maxworkers) as executor:
#
# ~/workspace/Droplet/venv/lib/python3.10/site-packages/tifffile/tifffile.py in ?(page, index, out, filecache, kwargs)
#   22598         ) -> None:
#   22599             # read, decode, and copy page data
#   22600             if page is not None:
#   22601                 filecache.open(page.parent.filehandle)
# > 22602                 page.asarray(lock=lock, out=out[index], **kwargs)
#   22603                 filecache.close(page.parent.filehandle)
#
# ~/workspace/Droplet/venv/lib/python3.10/site-packages/tifffile/tifffile.py in ?(self, *args, **kwargs)
#   10455         Parameters:
#   10456             **kwargs: Arguments passed to :py:meth:`TiffPage.asarray`.
#   10457
#   10458         """
# > 10459         return TiffPage.asarray(self, *args, **kwargs)  # type: ignore
#
# ~/workspace/Droplet/venv/lib/python3.10/site-packages/tifffile/tifffile.py in ?(self, out, squeeze, lock, maxworkers, buffersize)
#    9005                         f'{self!r} reading array from closed file', UserWarning
#    9006                     )
#    9007                     fh.open()
#    9008                 fh.seek(self.dataoffsets[0])
# -> 9009                 result = fh.read_array(
#    9010                     keyframe.parent.byteorder + keyframe._dtype.char,
#    9011                     product(keyframe.shaped),
#    9012                     out=out,
#
# ~/workspace/Droplet/venv/lib/python3.10/site-packages/tifffile/tifffile.py in ?(self, dtype, count, offset, out)
#   14504             self._fh.seek(self._offset + offset)
#   14505
#   14506         try:
#   14507             n = self._fh.readinto(result)  # type: ignore
# > 14508         except AttributeError:
#   14509             result[:] = numpy.frombuffer(self._fh.read(nbytes), dtype).reshape(
#   14510                 result.shape
#   14511             )
#
# KeyboardInterrupt:

# %% [markdown]
# ## Check crop area

# %%
xl = 100
xr = 200
yl = 100
yr = 200

# %%
""" Check crop area """

tmp = instance0.gray_images[0].copy()
cv2.rectangle(tmp, (xl, yl), (xr, yr), 0, 2)
display_images([tmp, instance0.gray_images[:, yl:yr, xl:xr][0], -instance0.gray_images[:, yl:yr, xl:xr][0]], ['original', 'cropped', 'cropped_nega'])

# %% [markdown]
# ## Set crop parameters in conf.json
#
# Remove the comment out to set crop parameters

# %%
# conf['crop'] = [xl, xr, yl, yr]
# save_yaml(conf, 'conf.yaml')
